# %%
from time import sleep, perf_counter
import pandas as pd

# %%
gdp_df = pd.read_csv("data/gdp.csv")
gdp_df = gdp_df[:266]
gdp_df.drop(columns=['Series Name', 'Series Code'], inplace=True)
gdp_df
# Out:
#                                    Country Name Country Code  \
# 0                                   Afghanistan          AFG
# 1                                       Albania          ALB
# 2                                       Algeria          DZA
# 3                                American Samoa          ASM
# 4                                       Andorra          AND
# ..                                          ...          ...
# 261                          Sub-Saharan Africa          SSF
# 262  Sub-Saharan Africa (excluding high income)          SSA
# 263   Sub-Saharan Africa (IDA & IBRD countries)          TSS
# 264                         Upper middle income          UMC
# 265                                       World          WLD
#
#         1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 0    62.3693745050559  62.4437034626929  60.9503638210144  82.0217375781519
# 1                  ..                ..                ..                ..
# ...

# %%
countries_noc_df = pd.read_csv("data/countries_noc.csv")
countries_noc_df
# Out:
#      noc                 country
# 0    AFG             Afghanistan
# 1    ALB                 Albania
# 2    ALG                 Algeria
# 3    ASA          American Samoa
# 4    AND                 Andorra
# ..   ...                     ...
# 229  WIF  West Indies Federation
# 230  YEM                   Yemen
# 231  YUG              Yugoslavia
# 232  ZAM                  Zambia
# 233  ZIM                Zimbabwe
#
# [234 rows x 2 columns]

# %%
gdp_df = gdp_df[gdp_df['Country Name'].isin(countries_noc_df['country'])]
gdp_df
# Out:
#        Country Name Country Code     1960 [YR1960]     1961 [YR1961]  \
# 0       Afghanistan          AFG  62.3693745050559  62.4437034626929
# 1           Albania          ALB                ..                ..
# 2           Algeria          DZA  239.033005807284  209.917177642367
# 3    American Samoa          ASM                ..                ..
# 4           Andorra          AND                ..                ..
# ..              ...          ...               ...               ...
# 207         Uruguay          URY  477.786990828994  624.718632584621
# 208      Uzbekistan          UZB                ..                ..
# 209         Vanuatu          VUT                ..                ..
# 215          Zambia          ZMB  228.567398531142  216.274673627806
# 216        Zimbabwe          ZWE  276.643363257328  279.332656130284
#
#         1962 [YR1962]     1963 [YR1963]     1964 [YR1964]     1965 [YR1965]  \
# ...

# %%
x = countries_noc_df[~countries_noc_df['country'].isin(gdp_df['Country Name'])]
x
# Out:
#      noc                                country
# 10   ANZ                            Australasia
# 23   BOH                                Bohemia
# 41   TPE                         Chinese Taipei
# 44   CGO                                  Congo
# 45   COK                           Cook Islands
# 47   CIV                          Côte d'Ivoire
# 48   CRT                                  Crete
# 53   TCH                         Czechoslovakia
# 54   PRK  Democratic People's Republic of Korea
# 55   COD       Democratic Republic of the Congo
# 60   GDR                           East Germany
# 62   EGY                                  Egypt
# 69   FSM         Federated States of Micronesia
# 77   GBR                          Great Britain
# 83   GBS                          Guinea Bissau
# 87   HKG                       Hong Kong, China
# 90   IOA           Independent Olympic Athletes
# 92   AIN            Individual Neutral Athletes
# 96   IRI               Islamic Republic of Iran
# ...
