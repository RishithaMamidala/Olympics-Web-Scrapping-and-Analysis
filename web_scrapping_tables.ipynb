# %%
from time import sleep, perf_counter
import concurrent.futures
from bs4 import BeautifulSoup 
import requests
import json
import gzip
import pandas as pd

# %%
host_cities = []
events_url = "https://www.olympedia.org/editions"
response = requests.get(events_url)
if response.status_code == 200:
    events_page = BeautifulSoup(response.content, "lxml")
    summer_table = events_page.find_all("table")[0]
    winter_table = events_page.find_all("table")[1]
    for row in summer_table.find_all("tr")[1:]:
        year = row.find_all('td')[1].text
        event = {
            "Year": year,
            "Season": "Summer",
            "Game": f"{year} Summer Olympics",
            "Host_City": row.find_all("td")[2].text
        }
        host_cities.append(event)
    for row in winter_table.find_all("tr")[1:]:
        year = row.find_all('td')[1].text
        event = {
            "Year": year,
            "Season": "Winter",
            "Game": f"{year} Winter Olympics",
            "Host_City": row.find_all("td")[2].text
        }
        host_cities.append(event)
else:
    print(response.raise_for_status())

# %%
host_cities_df = pd.DataFrame(host_cities)
host_cities_df.to_csv("data/host_cities.csv")
host_cities_df.head(5)
# Out:
#    Year  Season                  Game  Host_City
# 0  1896  Summer  1896 Summer Olympics     Athina
# 1  1900  Summer  1900 Summer Olympics      Paris
# 2  1904  Summer  1904 Summer Olympics  St. Louis
# 3  1908  Summer  1908 Summer Olympics     London
# 4  1912  Summer  1912 Summer Olympics  Stockholm

# %%
with open('data/athletes_urls.json', 'r') as file:
    athletes_urls = json.load(file)
print(len(athletes_urls))
athlete_total_content = []
# Out:
# 155943

# %%
def athletes_content(athlete_urls):
    response = requests.get(athlete_urls)
    if response.status_code == 200:
        athletes_page = BeautifulSoup(response.content, "lxml")
        name = athletes_page.find("h1")
        biography = athletes_page.find(attrs = {"class": "biodata"})
        game_result = athletes_page.find('table', attrs = {"class": "table"})
        content = "<div>" + str(name) + "\n" + f"<h4>{athlete_urls}</h4>" + str(biography) + "\n" + str(game_result) + "</div>"
        athlete_total_content.append(content)
    else:
        print(response.raise_for_status())

# %%
start = perf_counter()
with concurrent.futures.ThreadPoolExecutor(max_workers=50) as executor:
    executor.map(athletes_content, athletes_urls)
end = perf_counter()
print(f"Elapsed Time: {end-start:.3f} seconds")

# %%
with gzip.open("data/athletes_content.json.gz", 'wb') as file:
    file.write(json.dumps(athlete_total_content).encode('utf-8'))

# %%
with gzip.open("data/athletes_content.json.gz", 'rb') as file:
    decompressed_data = file.read().decode('utf-8')

total_athletes_content = json.loads(decompressed_data)

# %%
print(total_athletes_content[3])
# Out:
# <div><h1>
# Ángel Sposato
# </h1>
# <h4>https://www.olympedia.org/athletes/55113</h4><table class="biodata">
# <tr><th>Roles</th><td>Competed in Olympic Games</td></tr>
# <tr><th>Sex</th><td>Male</td></tr>
# <tr><th>Full name</th><td>Ángel Edmundo•Sposato</td></tr>
# <tr><th>Used name</th><td>Ángel•Sposato</td></tr>
# <tr><th>Born</th><td>17 May 1922</td></tr>
# <tr><th>Measurements</th><td>74 kg</td></tr>
# <tr><th>NOC</th><td><img src="https://olympedia-flags.s3.eu-central-1.amazonaws.com/ARG.png" style="padding-right: 2px; vertical-align: middle"/> <a href="/countries/ARG">Argentina</a></td></tr>
# </table>
# <table class="table">
# <thead>
# <tr>
# <th>Games</th>
# <th>Discipline (Sport) / Event</th>
# <th>NOC / Team</th>
# <th>Pos</th>
# <th>Medal</th>
# <th>As</th>
# <th></th>
# </tr>
# </thead>
# <tbody>
# <tr class="active">
# <td>
# <a href="/editions/13">1952 Summer Olympics</a>
# </td>
# <td><a href="/sports/WLF">Weightlifting</a></td>
# <td><a href="/countries/ARG"><img src="https://olympedia-flags.s3.eu-central-1.amazonaws.com/ARG.png" style="padding-right: 2px; vertical-align: middle"/>ARG</a></td>
# <td></td>
# <td></td>
# <td>Ángel Sposato</td>
# <td>
# </td>
# </tr>
# <tr>
# <td></td>
# <td>
# <a href="/results/29027">Middleweight, Men</a>
# <small>(Olympic)</small>
# </td>
# <td></td>
# <td>7</td>
# <td></td>
# <td></td>
# <td></td>
# </tr>
# </tbody>
# </table></div>

# %%
def extract_data(content):
    athletes_statistics = []
    athlete_info = BeautifulSoup(content, 'lxml')

    id = int(athlete_info.find("h4").text.split("/")[-1])
    name = athlete_info.find("h1").text.strip()
    gender, born, died, weight, height, noc = None, None, None, None, None, None
    biography = athlete_info.find(attrs = {"class":"biodata"}).find_all('tr')
    for row in biography:
        header = row.find("th").text
        data = row.find("td").text
        if header == "Sex":
            gender = data
        elif header == "Born":
            born = data.split('in')[0].strip()
        elif header == 'Died':
            died = data.split('in')[0].strip()
        elif header == "Measurements":
            measurements = data.split(' / ')
            if len(measurements) == 2: 
                height, weight = measurements 
            elif "kg" in data:
                weight = data
            elif "cm" in data:
                height = data
        elif header == 'NOC':
            noc = data.strip()
    
    biography_games_table = athlete_info.find('tbody').find_all('tr')
    game, sport, team = None, None, None
    event, position, medal = None, None, None
    game_temp = None
    for row in biography_games_table:
        if row.has_attr('class'):
            game, sport, team = [td.text.strip() for td in row.find_all('td')[:3]]
            if game != "":
                game_temp = game
            else:
                game = game_temp
        else:
            event = f"{sport}, {row.find_all('td')[1].text.strip('n')}".replace('\n', ''),
            position = row.find_all('td')[3].text,
            medal = row.find_all('td')[4].text
            athlete_data = {
                'id' : id,
                'name' : name,
                'gender' : gender,
                'born' : born,
                'died' : died,
                'height' : height,
                'weight' : weight,
                'noc' : noc,
                'game' : game,
                'team' : team,
                'sport' : sport,
                'event' : event,
                'position': position,
                'medal' : medal
            }
            athletes_statistics.append(athlete_data)
    return(athletes_statistics)

# %%
start = perf_counter()
with concurrent.futures.ThreadPoolExecutor(max_workers=50) as executor:
    all_athletes_data = list(executor.map(extract_data, total_athletes_content))   
end = perf_counter()
print(f"Elapsed Time: {end-start:.02f} seconds")
# Out:
# Elapsed Time: 844.90 seconds

# %%
flatten_athletes_data = []
for athlete_stats in all_athletes_data:
    for athlete_data in athlete_stats:
        flatten_athletes_data.append(athlete_data)

# %%
print(flatten_athletes_data[:6])
# Out:
# [{'id': 111427, 'name': 'Cui Peng', 'gender': 'Male', 'born': '31 May 1987', 'died': None, 'height': '179 cm', 'weight': '72 kg', 'noc': "People's Republic of China", 'game': '2008 Summer Olympics', 'team': 'CHN', 'sport': 'Football (Football)', 'event': ('Football (Football), Football, Men(Olympic)',), 'position': ('13',), 'medal': ''}, {'id': 97418, 'name': 'Muzaffer Selçuk', 'gender': 'Male', 'born': '12 August 1961', 'died': None, 'height': '180 cm', 'weight': '74 kg', 'noc': 'Türkiye', 'game': '1984 Winter Olympics', 'team': 'TUR', 'sport': 'Cross Country Skiing (Skiing)', 'event': ('Cross Country Skiing (Skiing), 15 kilometres, Men(Olympic)',), 'position': ('DNF',), 'medal': ''}, {'id': 18579, 'name': 'Georges Breuille', 'gender': 'Male', 'born': None, 'died': None, 'height': None, 'weight': None, 'noc': 'France', 'game': '1920 Summer Olympics', 'team': 'FRA', 'sport': 'Hockey', 'event': ('Hockey, Hockey, Men(Olympic)',), 'position': ('4',), 'medal': ''}, {'id': 55113, 'name': 'Ángel Sposato', 'gender': 'Male', 'born': '17 May 1922', 'died': None, 'height': None, 'weight': '74 kg', 'noc': 'Argentina', 'game': '1952 Summer Olympics', 'team': 'ARG', 'sport': 'Weightlifting', 'event': ('Weightlifting, Middleweight, Men(Olympic)',), 'position': ('7',), 'medal': ''}, {'id': 143768, 'name': 'Udayan Mane', 'gender': 'Male', 'born': '24 February 1991', 'died': None, 'height': '192 cm', 'weight': None, 'noc': 'India', 'game': '2020 Summer Olympics', 'team': 'IND', 'sport': 'Golf', 'event': ('Golf, Individual, Men(Olympic)',), 'position': ('56',), 'medal': ''}, {'id': 81239, 'name': 'Gillian Hamilton', 'gender': 'Female', 'born': '29 August 1969', 'died': None, 'height': '172 cm', 'weight': '57 kg', 'noc': 'Canada', 'game': '1994 Winter Olympics', 'team': 'CAN', 'sport': 'Biathlon', 'event': ('Biathlon, 7.5 kilometres Sprint, Women(Olympic)',), 'position': ('45',), 'medal': ''}]

# %%
athletes_data_df = pd.DataFrame(flatten_athletes_data)

# %%
host_cities_df = pd.read_csv("data/host_cities.csv")
host_cities_df
# Out:
#     Unnamed: 0  Year  Season                  Game                 Host_City
# 0            0  1896  Summer  1896 Summer Olympics                    Athina
# 1            1  1900  Summer  1900 Summer Olympics                     Paris
# 2            2  1904  Summer  1904 Summer Olympics                 St. Louis
# 3            3  1908  Summer  1908 Summer Olympics                    London
# 4            4  1912  Summer  1912 Summer Olympics                 Stockholm
# ..         ...   ...     ...                   ...                       ...
# 57          57  2010  Winter  2010 Winter Olympics                 Vancouver
# 58          58  2014  Winter  2014 Winter Olympics                     Sochi
# 59          59  2018  Winter  2018 Winter Olympics               PyeongChang
# 60          60  2022  Winter  2022 Winter Olympics                   Beijing
# 61          61  2026  Winter  2026 Winter Olympics  Milano-Cortina d'Ampezzo
#
# [62 rows x 5 columns]

# %%
host_cities_df.drop(columns=['Unnamed: 0'], inplace=True)
host_cities_df
# Out:
#     Year  Season                  Game                 Host_City
# 0   1896  Summer  1896 Summer Olympics                    Athina
# 1   1900  Summer  1900 Summer Olympics                     Paris
# 2   1904  Summer  1904 Summer Olympics                 St. Louis
# 3   1908  Summer  1908 Summer Olympics                    London
# 4   1912  Summer  1912 Summer Olympics                 Stockholm
# ..   ...     ...                   ...                       ...
# 57  2010  Winter  2010 Winter Olympics                 Vancouver
# 58  2014  Winter  2014 Winter Olympics                     Sochi
# 59  2018  Winter  2018 Winter Olympics               PyeongChang
# 60  2022  Winter  2022 Winter Olympics                   Beijing
# 61  2026  Winter  2026 Winter Olympics  Milano-Cortina d'Ampezzo
#
# [62 rows x 4 columns]

# %%
athletes_data_df
# Out:
#             id                 name  gender               born  \
# 0       111427             Cui Peng    Male        31 May 1987
# 1        97418      Muzaffer Selçuk    Male     12 August 1961
# 2        18579     Georges Breuille    Male               None
# 3        55113        Ángel Sposato    Male        17 May 1922
# 4       143768          Udayan Mane    Male   24 February 1991
# ...        ...                  ...     ...                ...
# 321423  145001           Lee Hye-In  Female    16 January 1995
# 321424   67556         Lauri Eskola    Male   16 November 1886
# 321425   67556         Lauri Eskola    Male   16 November 1886
# 321426  902192        Liu Chiu-Lung    Male  18 September 1956
# 321427   35780  Natallia Laurinenka  Female      30 March 1977
#
#                   died  height weight                         noc  \
# 0                 None  179 cm  72 kg  People's Republic of China
# 1                 None  180 cm  74 kg                     Türkiye
# 2                 None    None   None                      France
# 3                 None    None  74 kg                   Argentina
# 4                 None  192 cm   None                       India
# ...                ...     ...    ...                         ...
# 321423            None    None   None           Republic of Korea
# 321424  7 January 1958    None   None                     Finland
# 321425  7 January 1958    None   None                     Finland
# 321426            None    None   None              Chinese Taipei
# 321427            None  180 cm  74 kg                     Belarus
#
#                         game team                          sport  \
# 0       2008 Summer Olympics  CHN            Football (Football)
# 1       1984 Winter Olympics  TUR  Cross Country Skiing (Skiing)
# 2       1920 Summer Olympics  FRA                         Hockey
# 3       1952 Summer Olympics  ARG                  Weightlifting
# 4       2020 Summer Olympics  IND                           Golf
# ...                      ...  ...                            ...
# 321423  2020 Summer Olympics  KOR                        Fencing
# 321424  1912 Summer Olympics  FIN                      Athletics
# 321425  1912 Summer Olympics  FIN                      Athletics
# 321426  1984 Summer Olympics  TPE   Baseball (Baseball/Softball)
# 321427  1996 Summer Olympics  BLR                         Rowing
#
#                                                     event position   medal
# 0          (Football (Football), Football, Men(Olympic),)    (13,)
# 1       (Cross Country Skiing (Skiing), 15 kilometres,...   (DNF,)
# 2                         (Hockey, Hockey, Men(Olympic),)     (4,)
# 3            (Weightlifting, Middleweight, Men(Olympic),)     (7,)
# 4                       (Golf, Individual, Men(Olympic),)    (56,)
# ...                                                   ...      ...     ...
# 321423             (Fencing, Épée, Team, Women(Olympic),)     (2,)  Silver
# 321424  (Athletics, Cross-Country, Individual, Men(Oly...     (4,)
# 321425    (Athletics, Cross-Country, Team, Men(Olympic),)     (2,)  Silver
# 321426  (Baseball (Baseball/Softball), Baseball, Men(O...     (3,)
# 321427                  (Rowing, Eights, Women(Olympic),)     (3,)  Bronze
#
# [321428 rows x 14 columns]

# %%
#athletes_data_df.drop(columns=['Unnamed: 0'], axis = 1, inplace = True)                             
athletes_data_df.rename(columns = {"noc" : "team", "team" : "noc"}, inplace = True)  
athletes_data_df.isnull().sum()
# Out:
# id               0
# name             0
# gender           0
# born          5673
# died        241559
# height       81589
# weight       87665
# team             0
# game             0
# noc              0
# sport            0
# event            0
# position         0
# medal            0
# dtype: int64

# %%
athletes_data_df.fillna("NULL", inplace = True)                                      
athletes_data_df.to_csv("data/athletes_data.csv", index = False)

# %%
athletes_data_df
# Out:
#             id                 name  gender               born  \
# 0       111427             Cui Peng    Male        31 May 1987
# 1        97418      Muzaffer Selçuk    Male     12 August 1961
# 2        18579     Georges Breuille    Male               NULL
# 3        55113        Ángel Sposato    Male        17 May 1922
# 4       143768          Udayan Mane    Male   24 February 1991
# ...        ...                  ...     ...                ...
# 321423  145001           Lee Hye-In  Female    16 January 1995
# 321424   67556         Lauri Eskola    Male   16 November 1886
# 321425   67556         Lauri Eskola    Male   16 November 1886
# 321426  902192        Liu Chiu-Lung    Male  18 September 1956
# 321427   35780  Natallia Laurinenka  Female      30 March 1977
#
#                   died  height weight                        team  \
# 0                 NULL  179 cm  72 kg  People's Republic of China
# 1                 NULL  180 cm  74 kg                     Türkiye
# 2                 NULL    NULL   NULL                      France
# 3                 NULL    NULL  74 kg                   Argentina
# 4                 NULL  192 cm   NULL                       India
# ...                ...     ...    ...                         ...
# 321423            NULL    NULL   NULL           Republic of Korea
# 321424  7 January 1958    NULL   NULL                     Finland
# 321425  7 January 1958    NULL   NULL                     Finland
# 321426            NULL    NULL   NULL              Chinese Taipei
# 321427            NULL  180 cm  74 kg                     Belarus
#
#                         game  noc                          sport  \
# 0       2008 Summer Olympics  CHN            Football (Football)
# 1       1984 Winter Olympics  TUR  Cross Country Skiing (Skiing)
# 2       1920 Summer Olympics  FRA                         Hockey
# 3       1952 Summer Olympics  ARG                  Weightlifting
# 4       2020 Summer Olympics  IND                           Golf
# ...                      ...  ...                            ...
# 321423  2020 Summer Olympics  KOR                        Fencing
# 321424  1912 Summer Olympics  FIN                      Athletics
# 321425  1912 Summer Olympics  FIN                      Athletics
# 321426  1984 Summer Olympics  TPE   Baseball (Baseball/Softball)
# 321427  1996 Summer Olympics  BLR                         Rowing
#
#                                                     event position   medal
# 0          (Football (Football), Football, Men(Olympic),)    (13,)
# 1       (Cross Country Skiing (Skiing), 15 kilometres,...   (DNF,)
# 2                         (Hockey, Hockey, Men(Olympic),)     (4,)
# 3            (Weightlifting, Middleweight, Men(Olympic),)     (7,)
# 4                       (Golf, Individual, Men(Olympic),)    (56,)
# ...                                                   ...      ...     ...
# 321423             (Fencing, Épée, Team, Women(Olympic),)     (2,)  Silver
# 321424  (Athletics, Cross-Country, Individual, Men(Oly...     (4,)
# 321425    (Athletics, Cross-Country, Team, Men(Olympic),)     (2,)  Silver
# 321426  (Baseball (Baseball/Softball), Baseball, Men(O...     (3,)
# 321427                  (Rowing, Eights, Women(Olympic),)     (3,)  Bronze
#
# [321428 rows x 14 columns]

# %%
athletes_data_df[athletes_data_df['id'] == 1]
# Out:
#         id                   name gender              born            died  \
# 126687   1  Jean-François Blanchy   Male  12 December 1886  2 October 1960
# 126688   1  Jean-François Blanchy   Male  12 December 1886  2 October 1960
# 126689   1  Jean-François Blanchy   Male  12 December 1886  2 October 1960
# 126690   1  Jean-François Blanchy   Male  12 December 1886  2 October 1960
# 126691   1  Jean-François Blanchy   Male  12 December 1886  2 October 1960
#
#        height weight    team                  game  noc   sport  \
# 126687   NULL   NULL  France  1912 Summer Olympics  FRA  Tennis
# 126688   NULL   NULL  France  1912 Summer Olympics  FRA  Tennis
# 126689   NULL   NULL  France  1920 Summer Olympics  FRA  Tennis
# 126690   NULL   NULL  France  1920 Summer Olympics  FRA  Tennis
# 126691   NULL   NULL  France  1920 Summer Olympics  FRA  Tennis
#
#                                      event position medal
# 126687    (Tennis, Singles, Men(Olympic),)   (=17,)
# 126688    (Tennis, Doubles, Men(Olympic),)   (DNS,)
# 126689    (Tennis, Singles, Men(Olympic),)   (=32,)
# 126690  (Tennis, Doubles, Mixed(Olympic),)    (=8,)
# 126691    (Tennis, Doubles, Men(Olympic),)     (4,)

# %%
athletes_data_df['id'].nunique()
# Out:
# 155934

# %%
with gzip.open("data/athletes_content.json.gz", 'rb') as file:
    decompressed_data = file.read().decode('utf-8')

total_athletes_content = json.loads(decompressed_data)

# %%
def get_roles(athlete_data):
    
    athlete_info = BeautifulSoup(athlete_data, 'lxml')
    biography_table = athlete_info.find(attrs = {"class":"biodata"})
    
    if biography_table:
        biography = biography_table.find_all('tr')
        for row in biography:
            if row.find("th").text == 'Roles':   
                athlete_roles = {
                    'id' : int(athlete_info.find("h4").text.split("/")[-1]),
                    'name' : athlete_info.find("h1").text.strip(),
                    'roles' : row.find("td").text
                }
    return athlete_roles

# %%
start = perf_counter()
with concurrent.futures.ThreadPoolExecutor(max_workers=50) as executor:
    all_athletes_roles = list(executor.map(get_roles, total_athletes_content))   
end = perf_counter()
print(f"Elapsed Time: {end-start:.02f} seconds")
# Out:
# Elapsed Time: 1360.96 seconds

# %%
flattend_athletes_roles = [data for data in all_athletes_roles if data is not None]

# %%
athletes_roles_df = pd.DataFrame(flattend_athletes_roles)
athletes_roles_df.to_csv("data/athletes_roles.csv", index = False)
athletes_roles_df
# Out:
#             id                 name  \
# 0       111427             Cui Peng
# 1        97418      Muzaffer Selçuk
# 2        18579     Georges Breuille
# 3        55113        Ángel Sposato
# 4       143768          Udayan Mane
# ...        ...                  ...
# 155932   37771          Ralf Brudel
# 155933  145001           Lee Hye-In
# 155934   67556         Lauri Eskola
# 155935  902192        Liu Chiu-Lung
# 155936   35780  Natallia Laurinenka
#
#                                                roles
# 0                          Competed in Olympic Games
# 1                          Competed in Olympic Games
# 2                          Competed in Olympic Games
# 3                          Competed in Olympic Games
# 4                          Competed in Olympic Games
# ...                                              ...
# 155932                     Competed in Olympic Games
# 155933                     Competed in Olympic Games
# 155934                     Competed in Olympic Games
# 155935  Competed in Olympic Games (non-medal events)
# 155936                     Competed in Olympic Games
#
# [155937 rows x 3 columns]

# %%
athletes_data_df = pd.read_csv("data/athletes_data.csv")
athletes_data_df
# Out:
#             id                 name  gender               born  \
# 0       111427             Cui Peng    Male        31 May 1987
# 1        97418      Muzaffer Selçuk    Male     12 August 1961
# 2        18579     Georges Breuille    Male                NaN
# 3        55113        Ángel Sposato    Male        17 May 1922
# 4       143768          Udayan Mane    Male   24 February 1991
# ...        ...                  ...     ...                ...
# 321423  145001           Lee Hye-In  Female    16 January 1995
# 321424   67556         Lauri Eskola    Male   16 November 1886
# 321425   67556         Lauri Eskola    Male   16 November 1886
# 321426  902192        Liu Chiu-Lung    Male  18 September 1956
# 321427   35780  Natallia Laurinenka  Female      30 March 1977
#
#                   died  height weight                        team  \
# 0                  NaN  179 cm  72 kg  People's Republic of China
# 1                  NaN  180 cm  74 kg                     Türkiye
# 2                  NaN     NaN    NaN                      France
# 3                  NaN     NaN  74 kg                   Argentina
# 4                  NaN  192 cm    NaN                       India
# ...                ...     ...    ...                         ...
# 321423             NaN     NaN    NaN           Republic of Korea
# 321424  7 January 1958     NaN    NaN                     Finland
# 321425  7 January 1958     NaN    NaN                     Finland
# 321426             NaN     NaN    NaN              Chinese Taipei
# 321427             NaN  180 cm  74 kg                     Belarus
#
#                         game  noc                          sport  \
# 0       2008 Summer Olympics  CHN            Football (Football)
# 1       1984 Winter Olympics  TUR  Cross Country Skiing (Skiing)
# 2       1920 Summer Olympics  FRA                         Hockey
# 3       1952 Summer Olympics  ARG                  Weightlifting
# 4       2020 Summer Olympics  IND                           Golf
# ...                      ...  ...                            ...
# 321423  2020 Summer Olympics  KOR                        Fencing
# 321424  1912 Summer Olympics  FIN                      Athletics
# 321425  1912 Summer Olympics  FIN                      Athletics
# 321426  1984 Summer Olympics  TPE   Baseball (Baseball/Softball)
# 321427  1996 Summer Olympics  BLR                         Rowing
#
#                                                     event  position   medal
# 0        ('Football (Football), Football, Men(Olympic)',)   ('13',)     NaN
# 1       ('Cross Country Skiing (Skiing), 15 kilometres...  ('DNF',)     NaN
# 2                       ('Hockey, Hockey, Men(Olympic)',)    ('4',)     NaN
# 3          ('Weightlifting, Middleweight, Men(Olympic)',)    ('7',)     NaN
# 4                     ('Golf, Individual, Men(Olympic)',)   ('56',)     NaN
# ...                                                   ...       ...     ...
# 321423           ('Fencing, Épée, Team, Women(Olympic)',)    ('2',)  Silver
# 321424  ('Athletics, Cross-Country, Individual, Men(Ol...    ('4',)     NaN
# 321425  ('Athletics, Cross-Country, Team, Men(Olympic)',)    ('2',)  Silver
# 321426  ('Baseball (Baseball/Softball), Baseball, Men(...    ('3',)     NaN
# 321427                ('Rowing, Eights, Women(Olympic)',)    ('3',)  Bronze
#
# [321428 rows x 14 columns]

# %%
athletes_data_df.isnull().sum()
# Out:
# id          0
# name        0
# gender      0
# born        0
# died        0
# height      0
# weight      0
# team        0
# game        0
# noc         0
# sport       0
# event       0
# position    0
# medal       0
# dtype: int64

# %%
athletes_data_df[athletes_data_df['id'] == 13748]
# Out:
#         id         name gender             born  died  height weight  \
# 392  13748  Paul Brydon   Male  8 December 1951  NULL  173 cm   NULL
# 393  13748  Paul Brydon   Male  8 December 1951  NULL  173 cm   NULL
#
#             team                  game  noc                    sport  \
# 392  New Zealand  1972 Summer Olympics  NZL   Cycling Road (Cycling)
# 393  New Zealand  1972 Summer Olympics  NZL  Cycling Track (Cycling)
#
#                                                  event    position medal
# 392  (Cycling Road (Cycling), Road Race, Individual...       (50,)
# 393  (Cycling Track (Cycling), Team Pursuit, 4,000 ...  (14 r1/4,)
